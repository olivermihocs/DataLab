# %% [markdown]
# # Silver — Crypto Bronze to Silver
#
# > **TODO:** This notebook is a placeholder. The Silver ETL logic has not been implemented yet.
#
# **Planned responsibilities of this layer:**
# - Read from `s3a://warehouse/bronze/crypto`
# - Clean and validate data (null checks, outlier removal, type enforcement)
# - Enrich with derived columns (e.g. daily return %, 7-day moving average)
# - Deduplicate rows
# - Write to `s3a://warehouse/silver/crypto`
#
# **Parameters (Cell 2):**
# - `BRONZE_PATH` — source Delta table
# - `SILVER_PATH` — destination Delta table

# %%
BRONZE_PATH = "s3a://warehouse/bronze/crypto"
SILVER_PATH = "s3a://warehouse/silver/crypto"

# %%
raise NotImplementedError(
    "Silver ETL for crypto is not implemented yet. "
    "Set RUN_SILVER=False in the pipeline runner until this notebook is built."
)
